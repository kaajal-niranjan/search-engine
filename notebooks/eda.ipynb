# %% [markdown]
# # Product Catalog EDA
# Exploratory analysis for the semantic product search engine.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
import matplotlib.pyplot as plt
from src.preprocessing import run_preprocessing

df = run_preprocessing()
df.head()

# %%
df.isnull().sum()

# %%
df['category'].value_counts().plot(kind='bar', figsize=(10, 4), title='Category Distribution')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df[['price', 'rating']].hist(bins=20, figsize=(10, 3))
plt.tight_layout()
plt.show()
